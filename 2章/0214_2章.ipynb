# %% [markdown]
# # 2章 機械学習に必要な基礎統計学

# %% [markdown]
# ## データの種類

# %% [markdown]
# ### 問題2-1

# %% [markdown]
# 以下の①～⑦の部分のデータを、量的データ、質的データに分けてください。

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **解答欄**

# %%
# 量的データに該当する番号
# ①、③、④

# 質的データ（カテゴリカルデータ）に該当する番号
# ②、⑤、⑥、⑦

# %% [markdown]
# ## 基本統計量

# %% [markdown]
# ### 問題2-2

# %% [markdown]
# (1)以下のデータの最大値、最小値、中央値、平均値を求めてください
# ※Pythonを使わず、手計算で求めてください

# %% [markdown]
# |体重(kg)|
# | ----: |
# |53|
# |53|
# |55|
# |58|
# |61|

# %% [markdown]
# **解答欄**

# %%
#最大値
# 61

#最小値
# 53

#中央値
# 55

#平均値
# 56

# %% [markdown]
# (2)以下のデータの最大値、最小値、中央値、平均値を求めてください
# ※Pythonを使わず、手計算で求めてください

# %% [markdown]
# |体重(kg)|
# | ----: |
# |53|
# |53|
# |55|
# |58|
# |62|
# |64|

# %% [markdown]
# **解答欄**

# %%
#最大値
# 64

#最小値
# 53

#中央値
# 56.5

#平均値
# 57.5

# %% [markdown]
# ## 相関関係

# %% [markdown]
# ### 問題2-3

# %% [markdown]
# (1)以下の散布図が、正の相関、負の相関のどちらの傾向を示しているかを解答してください。

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **解答欄**

# %%
# 正の相関

# %% [markdown]
# (2)以下の散布図が、正の相関、負の相関のどちらの傾向を示しているかを解答してください。

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **解答欄**

# %%
# 負の相関

# %% [markdown]
# ## ヒストグラム

# %% [markdown]
# ### 問題2-4

# %% [markdown]
# 以下のヒストグラムについて、どちらのグラフのほうが分散の大きいデータを示しているかを解答してください。

# %% [markdown]
# A
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# B
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **解答欄**

# %% [markdown]
# 分散の大きいヒストグラム(A or B)

# %%
# A

# %% [markdown]
# ## 箱ひげ図

# %% [markdown]
# ### 問題2-5

# %% [markdown]
# 箱ひげ図の各箇所が示しているデータの内容を記載してください

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **解答欄**

# %%
#(1)の箇所
# 最大値

#(2)の箇所
# 第三四分位数

#(3)の箇所
# 中央値

#(4)の箇所
# 第一四分位数

#(5)の箇所
# 最小値

#(6)の箇所
# 外れ値
